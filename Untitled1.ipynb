# %% [markdown]
# <a href="https://colab.research.google.com/github/rociohbarroso/Bol-Label/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
from ultralytics import YOLO
from ultralytics.solutions import object_counter
import cv2

# %%
from moviepy.editor import *
video = VideoFileClip("/content/360_visionpanoramica.mp4")
cortado = video.subclip(0, 3)
cortado.write_videofile("cortado.mp4")

model = YOLO("yolov8n.pt")
cap = cv2.VideoCapture("/content/cortado.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
# Out:
# t:  43%|████▎     | 13/30 [01:00<00:01,  8.75it/s, now=None]
# Moviepy - Building video cortado.mp4.
# MoviePy - Writing audio in cortadoTEMP_MPY_wvf_snd.mp3
# ...
# t:  43%|████▎     | 13/30 [01:00<00:01,  8.75it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video cortado.mp4
# ...
# t:  43%|████▎     | 13/30 [02:02<00:01,  8.75it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready cortado.mp4

# %%
# Define region points
region_points = [(20, 400), (1080, 404), (1080, 360), (20, 360)]

# Video writer
video_writer = cv2.VideoWriter("object_counting_output.avi",
                       cv2.VideoWriter_fourcc(*'mp4v'),
                       fps,
                       (w, h))
# Init Object Counter
counter = object_counter.ObjectCounter()
counter.set_args(view_img=True,
                 reg_pts=region_points,
                 classes_names=model.names,
                 draw_tracks=True)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False)

    im0 = counter.start_counting(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Region Counter Initiated.
#
# 0: 320x640 2 boats, 166.5ms
# Speed: 5.0ms preprocess, 166.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 140.4ms
# Speed: 3.9ms preprocess, 140.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 149.5ms
# Speed: 3.8ms preprocess, 149.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 145.7ms
# Speed: 5.6ms preprocess, 145.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 140.3ms
# Speed: 5.5ms preprocess, 140.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 138.4ms
# Speed: 4.5ms preprocess, 138.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bus, 1 boat, 151.9ms
# ...

# %%
from ultralytics.solutions import heatmap

model = YOLO("yolov8n.pt")
cap = cv2.VideoCapture("/content/cortado.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer2 = cv2.VideoWriter("heatmap_output.avi",
                               cv2.VideoWriter_fourcc(*'mp4v'),
                               fps,
                               (w, h))
heatmap_obj = heatmap.Heatmap()
heatmap_obj.set_args(colormap=cv2.COLORMAP_OCEAN,
                     imw=w,
                     imh=h,
                     view_img=True,
                     shape="circle")

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False)

    im0 = heatmap_obj.generate_heatmap(im0, tracks)
    video_writer2.write(im0)

cap.release()
video_writer2.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# 0: 320x640 2 boats, 171.3ms
# Speed: 3.3ms preprocess, 171.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 146.1ms
# Speed: 3.4ms preprocess, 146.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 150.8ms
# Speed: 3.2ms preprocess, 150.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 147.2ms
# Speed: 3.2ms preprocess, 147.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 152.6ms
# Speed: 4.3ms preprocess, 152.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 boat, 138.1ms
# Speed: 3.2ms preprocess, 138.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 bus, 1 boat, 149.0ms
# ...
